# %%
from hrepr import hrepr

hrepr({
    'strings': "Hello this is hrepr",
    'numbers': [1, -2, 3.0],
    'booleans': (True, False),
    'none': None
})
# Out:
# <div class="hrepr-dict hrepr-titled-h"><div class="hrepr-title">{</div><div class="hrepr-contents-v"><table class="hrepr-object-table"><tr><td><span class="hrepr-str">strings</span></td><td class="hrepr-delimiter"> ↦ </td><td><span class="hrepr-str">Hello this is hrepr</span></td></tr><tr><td><span class="hrepr-str">numbers</span></td><td class="hrepr-delimiter"> ↦ </td><td><div class="hrepr-list hrepr-titled-h"><div class="hrepr-title">[</div><div class="hrepr-contents-h"><span class="hrepr-int">1</span><span class="hrepr-int">-2</span><span class="hrepr-float">3.0</span></div><div class="hrepr-title">]</div></div></td></tr><tr><td><span class="hrepr-str">booleans</span></td><td class="hrepr-delimiter"> ↦ </td><td><div class="hrepr-tuple hrepr-titled-h"><div class="hrepr-title">(</div><div class="hrepr-contents-h"><span class="hrepr-True hrepr-bool">True</span><span class="hrepr-bool hrepr-False">False</span></div><div class="hrepr-title">)</div></div></td></tr><tr><td><span class="hrepr-str">none</span></td><td class="hrepr-delimiter"> ↦ </td><td><span class="hrepr-NoneType">None</span></td></tr></table></div><div class="hrepr-title">}</div></div>

# %%
from IPython.display import display_html

class Person:
    def __init__(self, name, age, job):
        self.name = name
        self.age = age
        self.job = job

    def __hrepr__(self, H, hrepr):
        return hrepr.stdrepr_object(self.name, [('age', self.age), ('job', self.job)])

    def __hrepr_short__(self, H, hrepr):
        return H.strong(self.name, style='color:blue')

alice = Person('Alice', 46, 'chef')

display_html(hrepr(alice))               # Triggers __hrepr__
display_html(hrepr(alice, max_depth=0))  # Triggers __hrepr_short__ at given depth
# Out:
# <div><style>/*
#  * Override Jupyter's default css inside elements with the hrepr class.
#  */
#
# .hrepr td {
# 	text-align: left;
# }
# </style><style>
# :root, :host {
# 	--object-color: #00a;
# 	--dict-color: #00a;
# 	--tuple-color: #080;
# 	--list-color: #080;
# 	--set-color: #080;
# 	--frozenset-color: #88f;
# 	--titled-box-radius: 0px;
# }
#
# /* Scalar/string formatting */
#
# .hrepr-True, .hrepr-False, .hrepr-NoneType, .hrepr-int, .hrepr-float {
# 	font-weight: bold;
# }
#
# .hrepr-int, .hrepr-float {
# 	color: #88f;
# }
#
# .hrepr-str {
# 	color: #666;
# 	white-space: pre;
# }
#
# .hrepr-str:before {
# 	content: "“";
# 	color: #888;
# }
#
# .hrepr-str:after {
# 	content: "”";
# 	color: #888;
# }
#
# .hrepr-True {
# 	color: green;
# }
#
# .hrepr-False {
# 	color: red;
# }
#
# .hrepr-NoneType {
# 	color: grey;
# }
#
# /* Generic object formatting */
#
# .hrepr-title {
# 	background: var(--object-color);
# 	color: white;
# 	vertical-align: middle;
# 	display: flex;
# 	align-items: center;
# }
#
# .hrepr-titled-v > .hrepr-title {
# 	font-weight: bold;
# 	padding-left: 5px;
# 	padding-right: 5px;
# 	padding-top: 2px;
# 	padding-bottom: 2px;
# }
#
# .hrepr-titled-h > .hrepr-title {
# 	padding-left: 2px;
# 	padding-right: 2px;
# }
#
# .hrepr-titled-h > .hrepr-title:first-child {
# 	padding-right: 5px;
# }
#
# .hrepr-titled-h > .hrepr-title:last-child {
# 	padding-left: 5px;
# }
#
# .hrepr-titled-h, .hrepr-contents-h {
# 	display: flex;
# 	flex-direction: row;
# }
#
# .hrepr-titled-v, .hrepr-contents-v {
# 	display: flex;
# 	flex-direction: column;
# }
#
# .hrepr-titled-h, .hrepr-titled-v {
# 	display: inline-flex;
# 	border: 1px solid var(--object-color);
# 	border-radius: var(--titled-box-radius);
# 	background: #fff;
# }
#
# .hrepr-contents-h {
# 	align-items: center;
# 	flex-wrap: wrap;
# }
#
# .hrepr-contents-h > * {
# 	margin-left: 2px;
# 	margin-right: 2px;
# }
#
# .hrepr-contents-h > :nth-child(odd),
# .hrepr-contents-v > :nth-child(odd),
# .hrepr-object-table > tbody > tr:nth-child(odd) {
# 	background: #fff;
# }
#
# .hrepr-contents-h > :nth-child(even),
# .hrepr-contents-v > :nth-child(even),
# .hrepr-object-table > tbody > tr:nth-child(even) {
# 	background: #ddd;
# }
#
# .hrepr-object-table {
# 	display: inline-block;
# 	border-collapse: collapse;
# 	width: 100%;
# 	border-radius: var(--titled-box-radius);
# }
#
# .hrepr-object-table > tbody > tr > td {
# 	padding-left: 5px;
# 	padding-right: 5px;
# }
#
# .hrepr-object-table > tbody > tr > td.hrepr-delimiter {
# 	padding: 0px;
# }
#
# /* .hrepr-object-table > tbody > tr > td > * {
# 	display: inline-block;
# } */
#
# .hrepr-object-kvpair {
# 	padding-left: 5px;
# 	padding-right: 5px;
# 	background: #eee;
# }
#
# /* Colorize boxes for standard data structures */
#
# .hrepr-dict { border: 1px solid var(--dict-color); }
# .hrepr-dict > .hrepr-title { background: var(--dict-color); }
#
# .hrepr-tuple { border: 1px solid var(--tuple-color); }
# .hrepr-tuple > .hrepr-title { background: var(--tuple-color); }
#
# .hrepr-list { border: 1px solid var(--list-color); }
# .hrepr-list > .hrepr-title { background: var(--list-color); }
#
# .hrepr-set { border: 1px solid var(--set-color); }
# .hrepr-set > .hrepr-title { background: var(--set-color); }
#
# .hrepr-frozenset { border: 1px solid var(--frozenset-color); }
# .hrepr-frozenset > .hrepr-title { background: var(--frozenset-color); }
#
# .hrepr-ellipsis {
# 	font-weight: bold;
# }
#
# .hrepr-circular {
# 	font-weight: bold;
# 	color: magenta;
# }
# </style><div class="hrepr"><div class="hrepr-titled-v"><div class="hrepr-title">Alice</div><div class="hrepr-contents-v"><table class="hrepr-object-table"><tr><td>age</td><td><span class="hrepr-int">46</span></td></tr><tr><td>job</td><td><span class="hrepr-str">chef</span></td></tr></table></div></div></div></div>
# <div><style>/*
#  * Override Jupyter's default css inside elements with the hrepr class.
#  */
#
# .hrepr td {
# 	text-align: left;
# }
# </style><style>
# :root, :host {
# 	--object-color: #00a;
# 	--dict-color: #00a;
# 	--tuple-color: #080;
# 	--list-color: #080;
# 	--set-color: #080;
# 	--frozenset-color: #88f;
# 	--titled-box-radius: 0px;
# }
#
# /* Scalar/string formatting */
#
# .hrepr-True, .hrepr-False, .hrepr-NoneType, .hrepr-int, .hrepr-float {
# 	font-weight: bold;
# }
#
# .hrepr-int, .hrepr-float {
# 	color: #88f;
# }
#
# .hrepr-str {
# 	color: #666;
# 	white-space: pre;
# }
#
# .hrepr-str:before {
# 	content: "“";
# 	color: #888;
# }
#
# .hrepr-str:after {
# 	content: "”";
# 	color: #888;
# }
#
# .hrepr-True {
# 	color: green;
# }
#
# .hrepr-False {
# 	color: red;
# }
#
# .hrepr-NoneType {
# 	color: grey;
# }
#
# /* Generic object formatting */
#
# .hrepr-title {
# 	background: var(--object-color);
# 	color: white;
# 	vertical-align: middle;
# 	display: flex;
# 	align-items: center;
# }
#
# .hrepr-titled-v > .hrepr-title {
# 	font-weight: bold;
# 	padding-left: 5px;
# 	padding-right: 5px;
# 	padding-top: 2px;
# 	padding-bottom: 2px;
# }
#
# .hrepr-titled-h > .hrepr-title {
# 	padding-left: 2px;
# 	padding-right: 2px;
# }
#
# .hrepr-titled-h > .hrepr-title:first-child {
# 	padding-right: 5px;
# }
#
# .hrepr-titled-h > .hrepr-title:last-child {
# 	padding-left: 5px;
# }
#
# .hrepr-titled-h, .hrepr-contents-h {
# 	display: flex;
# 	flex-direction: row;
# }
#
# .hrepr-titled-v, .hrepr-contents-v {
# 	display: flex;
# 	flex-direction: column;
# }
#
# .hrepr-titled-h, .hrepr-titled-v {
# 	display: inline-flex;
# 	border: 1px solid var(--object-color);
# 	border-radius: var(--titled-box-radius);
# 	background: #fff;
# }
#
# .hrepr-contents-h {
# 	align-items: center;
# 	flex-wrap: wrap;
# }
#
# .hrepr-contents-h > * {
# 	margin-left: 2px;
# 	margin-right: 2px;
# }
#
# .hrepr-contents-h > :nth-child(odd),
# .hrepr-contents-v > :nth-child(odd),
# .hrepr-object-table > tbody > tr:nth-child(odd) {
# 	background: #fff;
# }
#
# .hrepr-contents-h > :nth-child(even),
# .hrepr-contents-v > :nth-child(even),
# .hrepr-object-table > tbody > tr:nth-child(even) {
# 	background: #ddd;
# }
#
# .hrepr-object-table {
# 	display: inline-block;
# 	border-collapse: collapse;
# 	width: 100%;
# 	border-radius: var(--titled-box-radius);
# }
#
# .hrepr-object-table > tbody > tr > td {
# 	padding-left: 5px;
# 	padding-right: 5px;
# }
#
# .hrepr-object-table > tbody > tr > td.hrepr-delimiter {
# 	padding: 0px;
# }
#
# /* .hrepr-object-table > tbody > tr > td > * {
# 	display: inline-block;
# } */
#
# .hrepr-object-kvpair {
# 	padding-left: 5px;
# 	padding-right: 5px;
# 	background: #eee;
# }
#
# /* Colorize boxes for standard data structures */
#
# .hrepr-dict { border: 1px solid var(--dict-color); }
# .hrepr-dict > .hrepr-title { background: var(--dict-color); }
#
# .hrepr-tuple { border: 1px solid var(--tuple-color); }
# .hrepr-tuple > .hrepr-title { background: var(--tuple-color); }
#
# .hrepr-list { border: 1px solid var(--list-color); }
# .hrepr-list > .hrepr-title { background: var(--list-color); }
#
# .hrepr-set { border: 1px solid var(--set-color); }
# .hrepr-set > .hrepr-title { background: var(--set-color); }
#
# .hrepr-frozenset { border: 1px solid var(--frozenset-color); }
# .hrepr-frozenset > .hrepr-title { background: var(--frozenset-color); }
#
# .hrepr-ellipsis {
# 	font-weight: bold;
# }
#
# .hrepr-circular {
# 	font-weight: bold;
# 	color: magenta;
# }
# </style><div class="hrepr"><strong style="color:blue">Alice</strong></div></div>

# %%
class Color:
    def __init__(self, r, g, b):
        self.r = r
        self.g = g
        self.b = b

    def __hrepr__(self, H, hrepr):
        size = hrepr.config.swatch_size or 25
        style = f"""
        background: rgb({self.r}, {self.g}, {self.b});
        width: {size}px;
        height: {size}px;
        margin: 3px;
        """
        return H.div(style=style)

hrepr([Color(i*16, 0, 0) for i in range(17)], swatch_size=20)
# Out:
# <div class="hrepr-list hrepr-titled-h"><div class="hrepr-title">[</div><div class="hrepr-contents-h"><div style="
#         background: rgb(0, 0, 0);
#         width: 20px;
#         height: 20px;
#         margin: 3px;
#         "></div><div style="
#         background: rgb(16, 0, 0);
#         width: 20px;
#         height: 20px;
#         margin: 3px;
#         "></div><div style="
#         background: rgb(32, 0, 0);
#         width: 20px;
#         height: 20px;
#         margin: 3px;
#         "></div><div style="
#         background: rgb(48, 0, 0);
#         width: 20px;
#         height: 20px;
#         margin: 3px;
#         "></div><div style="
#         background: rgb(64, 0, 0);
#         width: 20px;
#         height: 20px;
#         margin: 3px;
#         "></div><div style="
#         background: rgb(80, 0, 0);
#         width: 20px;
#         height: 20px;
#         margin: 3px;
#         "></div><div style="
#         background: rgb(96, 0, 0);
#         width: 20px;
#         height: 20px;
#         margin: 3px;
#         "></div><div style="
#         background: rgb(112, 0, 0);
#         width: 20px;
#         height: 20px;
#         margin: 3px;
#         "></div><div style="
#         background: rgb(128, 0, 0);
#         width: 20px;
#         height: 20px;
#         margin: 3px;
#         "></div><div style="
#         background: rgb(144, 0, 0);
#         width: 20px;
#         height: 20px;
#         margin: 3px;
#         "></div><div style="
#         background: rgb(160, 0, 0);
#         width: 20px;
#         height: 20px;
#         margin: 3px;
#         "></div><div style="
#         background: rgb(176, 0, 0);
#         width: 20px;
#         height: 20px;
#         margin: 3px;
#         "></div><div style="
#         background: rgb(192, 0, 0);
#         width: 20px;
#         height: 20px;
#         margin: 3px;
#         "></div><div style="
#         background: rgb(208, 0, 0);
#         width: 20px;
#         height: 20px;
#         margin: 3px;
#         "></div><div style="
#         background: rgb(224, 0, 0);
#         width: 20px;
#         height: 20px;
#         margin: 3px;
#         "></div><div style="
#         background: rgb(240, 0, 0);
#         width: 20px;
#         height: 20px;
#         margin: 3px;
#         "></div><div style="
#         background: rgb(256, 0, 0);
#         width: 20px;
#         height: 20px;
#         margin: 3px;
#         "></div></div><div class="hrepr-title">]</div></div>

# %%
hrepr([{i: i * i} for i in range(10)], max_depth=1)
# Out:
# <div class="hrepr-list hrepr-titled-h"><div class="hrepr-title">[</div><div class="hrepr-contents-h"><div class="hrepr-dict hrepr-titled-h"><div class="hrepr-title">{</div><div class="hrepr-contents-h"><span class="hrepr-ellipsis">⋮</span></div><div class="hrepr-title">}</div></div><div class="hrepr-dict hrepr-titled-h"><div class="hrepr-title">{</div><div class="hrepr-contents-h"><span class="hrepr-ellipsis">⋮</span></div><div class="hrepr-title">}</div></div><div class="hrepr-dict hrepr-titled-h"><div class="hrepr-title">{</div><div class="hrepr-contents-h"><span class="hrepr-ellipsis">⋮</span></div><div class="hrepr-title">}</div></div><div class="hrepr-dict hrepr-titled-h"><div class="hrepr-title">{</div><div class="hrepr-contents-h"><span class="hrepr-ellipsis">⋮</span></div><div class="hrepr-title">}</div></div><div class="hrepr-dict hrepr-titled-h"><div class="hrepr-title">{</div><div class="hrepr-contents-h"><span class="hrepr-ellipsis">⋮</span></div><div class="hrepr-title">}</div></div><div class="hrepr-dict hrepr-titled-h"><div class="hrepr-title">{</div><div class="hrepr-contents-h"><span class="hrepr-ellipsis">⋮</span></div><div class="hrepr-title">}</div></div><div class="hrepr-dict hrepr-titled-h"><div class="hrepr-title">{</div><div class="hrepr-contents-h"><span class="hrepr-ellipsis">⋮</span></div><div class="hrepr-title">}</div></div><div class="hrepr-dict hrepr-titled-h"><div class="hrepr-title">{</div><div class="hrepr-contents-h"><span class="hrepr-ellipsis">⋮</span></div><div class="hrepr-title">}</div></div><div class="hrepr-dict hrepr-titled-h"><div class="hrepr-title">{</div><div class="hrepr-contents-h"><span class="hrepr-ellipsis">⋮</span></div><div class="hrepr-title">}</div></div><div class="hrepr-dict hrepr-titled-h"><div class="hrepr-title">{</div><div class="hrepr-contents-h"><span class="hrepr-ellipsis">⋮</span></div><div class="hrepr-title">}</div></div></div><div class="hrepr-title">]</div></div>

# %%
class MyIntRepr:
    def resources(self, H):
        return H.style(".my-integer { color: fuchsia; }")

    def __call__(self, n, H, hrepr):
        return H.span['my-integer']('The number ', str(n))

hrepr([1, 2, 3, 4], type_handlers={int: MyIntRepr()})
# Out:
# <div class="hrepr-list hrepr-titled-h"><div class="hrepr-title">[</div><div class="hrepr-contents-h"><span class="my-integer">The number 1</span><span class="my-integer">The number 2</span><span class="my-integer">The number 3</span><span class="my-integer">The number 4</span></div><div class="hrepr-title">]</div></div>

# %%
# Another way to do the same thing

def mystr_repr(s, H, hrepr):
    return H.span['my-str'](s.upper())

def mystr_resources(H):
    return H.style(".my-str { font-weight: bold; }")

hrepr(['avocado', 'banana', 'cherry'], type_handlers={str: mystr_repr}, resources=mystr_resources)
# Out:
# <div class="hrepr-list hrepr-titled-h"><div class="hrepr-title">[</div><div class="hrepr-contents-h"><span class="my-str">AVOCADO</span><span class="my-str">BANANA</span><span class="my-str">CHERRY</span></div><div class="hrepr-title">]</div></div>

# %%
def highlighter(*objs):
    def post(obj, elem, H, hrepr):
        if obj in objs:
            return elem['highlight']  # This is simply a copy of elem with the 'highlight' class tacked on
    return post

def hl_resources(H):
    return H.style(".highlight { background: red !IMPORTANT; color: white !IMPORTANT; }")

hrepr([-2, -1, 0, 1, 2], postprocess=highlighter(-1, 0, 2), resources=hl_resources)
# Out:
# <div class="hrepr-list hrepr-titled-h"><div class="hrepr-title">[</div><div class="hrepr-contents-h"><span class="hrepr-int">-2</span><span class="hrepr-int highlight">-1</span><span class="hrepr-int highlight">0</span><span class="hrepr-int">1</span><span class="hrepr-int highlight">2</span></div><div class="hrepr-title">]</div></div>

# %%
def no_underscores(obj, hrepr):
    if isinstance(obj, dict):
        return {k: v for k, v in obj.items() if not k.startswith('_')}
    else:
        return obj

hrepr({'hello': 1, '_secret': 2, 'xyz': 3}, preprocess=no_underscores)
# Out:
# <div class="hrepr-dict hrepr-titled-h"><div class="hrepr-title">{</div><div class="hrepr-contents-v"><table class="hrepr-object-table"><tr><td><span class="hrepr-str">hello</span></td><td class="hrepr-delimiter"> ↦ </td><td><span class="hrepr-int">1</span></td></tr><tr><td><span class="hrepr-str">xyz</span></td><td class="hrepr-delimiter"> ↦ </td><td><span class="hrepr-int">3</span></td></tr></table></div><div class="hrepr-title">}</div></div>
